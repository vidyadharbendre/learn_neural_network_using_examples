# %% [markdown]
# # Boston housing price regression dataset
# Dataset taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# Samples contain 13 attributes of houses at different locations around the Boston suburbs in the late 1970s. Targets are the median values of the houses at a location (in k$).

# %% [markdown]
# Firstly, let's select TensorFlow version 2.x in colab

# %%
# %tensorflow_version 2.x
import tensorflow
tensorflow.__version__
# Out:
# TensorFlow 2.x selected.
# '2.1.0'

# %%
# Initialize the random number generator
import random
random.seed(0)

# Ignore the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Import dataset
# - This dataset can be imported
# - High level API Keras has some datasets available
# - You can look at all the datasets available here https://keras.io/datasets/

# %%
from tensorflow.keras.datasets import boston_housing

# boston_housing.load_data() function returns 2 tuples, one for train data and 
# other for test data. We will take only train data here.
(features, actual_prices), _ = boston_housing.load_data(test_split=0)

# %% [markdown]
# ### Getting details of dataset
# - We will see how many rows are there in the data
# - We will check how many features are there

# %%
print('Number of examples: ', features.shape[0])
print('Number of features for each example: ', features.shape[1])
print('Shape of actual prices data: ', actual_prices.shape)
# Out:
# Number of examples:  506
# Number of features for each example:  13
# Shape of actual prices data:  (506,)

# %% [markdown]
# Let's see some values of features and labels from the dataset

# %%
features[:5]
# Out:
# array([[1.23247e+00, 0.00000e+00, 8.14000e+00, 0.00000e+00, 5.38000e-01,
#         6.14200e+00, 9.17000e+01, 3.97690e+00, 4.00000e+00, 3.07000e+02,
#         2.10000e+01, 3.96900e+02, 1.87200e+01],
#        [2.17700e-02, 8.25000e+01, 2.03000e+00, 0.00000e+00, 4.15000e-01,
#         7.61000e+00, 1.57000e+01, 6.27000e+00, 2.00000e+00, 3.48000e+02,
#         1.47000e+01, 3.95380e+02, 3.11000e+00],
#        [4.89822e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 6.31000e-01,
#         4.97000e+00, 1.00000e+02, 1.33250e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.75520e+02, 3.26000e+00],
#        [3.96100e-02, 0.00000e+00, 5.19000e+00, 0.00000e+00, 5.15000e-01,
#         6.03700e+00, 3.45000e+01, 5.98530e+00, 5.00000e+00, 2.24000e+02,
#         2.02000e+01, 3.96900e+02, 8.01000e+00],
#        [3.69311e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 7.13000e-01,
#         6.37600e+00, 8.84000e+01, 2.56710e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.91430e+02, 1.46500e+01]])

# %%
actual_prices[:5]
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7])

# %% [markdown]
# ### Build the model
# - The Sequential model is a linear stack of layers.
# - The model needs to know what input shape it should expect. For this reason, the first layer in a Sequential model (and only the first, because following layers can do automatic shape inference) needs to receive information about its input shape.
# - You can also simply add layers via the .add() method

# %%
# Initialize Sequential model
model = tensorflow.keras.models.Sequential()

# Normalize input data
model.add(tensorflow.keras.layers.BatchNormalization(input_shape=(13,)))

# Add final Dense layer for prediction - Tensorflow.keras declares weights and bias automatically
model.add(tensorflow.keras.layers.Dense(1))

# %% [markdown]
# ### Compile the model
# - Here we configure the model for training
# - We will specify an optimizer and a loss function

# %%
# Compile the model - add mean squared error as loss and stochastic gradient descent as optimizer
model.compile(optimizer='sgd', loss='mse')

# %% [markdown]
# ### Fit the model
# - .fit() trains the model for a fixed number of epochs (iterations on a dataset)
# - An epoch is an iteration over the entire x and y data provided

# %%
model.fit(features, actual_prices, epochs=100, validation_split=0.35)
# Out:
# Train on 328 samples, validate on 178 samples
# Epoch 1/100
# 328/328 [==============================] - 2s 6ms/sample - loss: 306.9393 - val_loss: 2740.1189
# Epoch 2/100
# 328/328 [==============================] - 0s 136us/sample - loss: 41.5236 - val_loss: 1153.7925
# Epoch 3/100
# 328/328 [==============================] - 0s 120us/sample - loss: 33.9956 - val_loss: 411.9469
# Epoch 4/100
# 328/328 [==============================] - 0s 125us/sample - loss: 29.1531 - val_loss: 87.8055
# Epoch 5/100
# 328/328 [==============================] - 0s 128us/sample - loss: 31.4682 - val_loss: 194.5360
# Epoch 6/100
# 328/328 [==============================] - 0s 127us/sample - loss: 28.0829 - val_loss: 95.8689
# Epoch 7/100
# 328/328 [==============================] - 0s 124us/sample - loss: 29.8978 - val_loss: 33.7202
# Epoch 8/100
# 328/328 [==============================] - 0s 114us/sample - loss: 26.2121 - val_loss: 27.2575
# Epoch 9/100
# 328/328 [==============================] - 0s 130us/sample - loss: 32.5523 - val_loss: 77.0305
# Epoch 10/100
# 328/328 [==============================] - 0s 120us/sample - loss: 29.2996 - val_loss: 27.4448
# Epoch 11/100
# 328/328 [==============================] - 0s 123us/sample - loss: 34.0929 - val_loss: 42.1715
# Epoch 12/100
# 328/328 [==============================] - 0s 122us/sample - loss: 32.3653 - val_loss: 89.8343
# Epoch 13/100
# 328/328 [==============================] - 0s 126us/sample - loss: 38.1422 - val_loss: 52.4393
# Epoch 14/100
# 328/328 [==============================] - 0s 132us/sample - loss: 28.3231 - val_loss: 29.2207
# Epoch 15/100
# 328/328 [==============================] - 0s 175us/sample - loss: 29.3747 - val_loss: 56.2297
# Epoch 16/100
# 328/328 [==============================] - 0s 130us/sample - loss: 39.0442 - val_loss: 67.2584
# Epoch 17/100
# 328/328 [==============================] - 0s 126us/sample - loss: 29.3788 - val_loss: 86.6930
# Epoch 18/100
# 328/328 [==============================] - 0s 144us/sample - loss: 33.0909 - val_loss: 24.7275
# Epoch 19/100
# 328/328 [==============================] - 0s 134us/sample - loss: 29.9021 - val_loss: 36.3543
# Epoch 20/100
# 328/328 [==============================] - 0s 122us/sample - loss: 35.3612 - val_loss: 43.9821
# Epoch 21/100
# 328/328 [==============================] - 0s 117us/sample - loss: 43.0794 - val_loss: 71.8521
# Epoch 22/100
# 328/328 [==============================] - 0s 124us/sample - loss: 31.1932 - val_loss: 26.2647
# Epoch 23/100
# 328/328 [==============================] - 0s 131us/sample - loss: 28.3667 - val_loss: 27.9740
# Epoch 24/100
# 328/328 [==============================] - 0s 125us/sample - loss: 29.2098 - val_loss: 56.3511
# Epoch 25/100
# 328/328 [==============================] - 0s 130us/sample - loss: 34.6430 - val_loss: 35.0258
# Epoch 26/100
# 328/328 [==============================] - 0s 131us/sample - loss: 29.7565 - val_loss: 25.9414
# Epoch 27/100
# 328/328 [==============================] - 0s 146us/sample - loss: 25.9178 - val_loss: 27.1165
# Epoch 28/100
# 328/328 [==============================] - 0s 135us/sample - loss: 27.9791 - val_loss: 27.4627
# Epoch 29/100
# 328/328 [==============================] - 0s 125us/sample - loss: 26.2341 - val_loss: 35.9701
# Epoch 30/100
# 328/328 [==============================] - 0s 121us/sample - loss: 30.8436 - val_loss: 87.7431
# Epoch 31/100
# 328/328 [==============================] - 0s 122us/sample - loss: 34.0731 - val_loss: 24.6533
# Epoch 32/100
# 328/328 [==============================] - 0s 117us/sample - loss: 27.4072 - val_loss: 26.8360
# Epoch 33/100
# 328/328 [==============================] - 0s 117us/sample - loss: 28.8429 - val_loss: 51.0448
# Epoch 34/100
# 328/328 [==============================] - 0s 120us/sample - loss: 32.7665 - val_loss: 40.5836
# Epoch 35/100
# 328/328 [==============================] - 0s 117us/sample - loss: 29.7302 - val_loss: 26.7103
# Epoch 36/100
# 328/328 [==============================] - 0s 117us/sample - loss: 27.2392 - val_loss: 23.7939
# Epoch 37/100
# 328/328 [==============================] - 0s 131us/sample - loss: 26.7565 - val_loss: 25.8422
# Epoch 38/100
# 328/328 [==============================] - 0s 175us/sample - loss: 26.2016 - val_loss: 34.5171
# Epoch 39/100
# 328/328 [==============================] - 0s 127us/sample - loss: 27.2586 - val_loss: 35.3898
# Epoch 40/100
# 328/328 [==============================] - 0s 136us/sample - loss: 30.8849 - val_loss: 25.9150
# Epoch 41/100
# 328/328 [==============================] - 0s 147us/sample - loss: 24.6300 - val_loss: 25.4985
# Epoch 42/100
# 328/328 [==============================] - 0s 151us/sample - loss: 27.2057 - val_loss: 24.9828
# Epoch 43/100
# 328/328 [==============================] - 0s 134us/sample - loss: 30.4117 - val_loss: 23.9699
# Epoch 44/100
# 328/328 [==============================] - 0s 123us/sample - loss: 27.6078 - val_loss: 31.1030
# Epoch 45/100
# 328/328 [==============================] - 0s 128us/sample - loss: 24.2447 - val_loss: 44.8415
# Epoch 46/100
# 328/328 [==============================] - 0s 132us/sample - loss: 25.4568 - val_loss: 34.6813
# Epoch 47/100
# 328/328 [==============================] - 0s 125us/sample - loss: 25.2843 - val_loss: 26.0713
# Epoch 48/100
# 328/328 [==============================] - 0s 121us/sample - loss: 28.2644 - val_loss: 44.3984
# Epoch 49/100
# 328/328 [==============================] - 0s 127us/sample - loss: 29.7829 - val_loss: 57.4581
# Epoch 50/100
# 328/328 [==============================] - 0s 129us/sample - loss: 31.3405 - val_loss: 31.1825
# Epoch 51/100
# 328/328 [==============================] - 0s 138us/sample - loss: 25.3692 - val_loss: 29.7961
# Epoch 52/100
# 328/328 [==============================] - 0s 127us/sample - loss: 37.5720 - val_loss: 31.2271
# Epoch 53/100
# 328/328 [==============================] - 0s 133us/sample - loss: 27.8348 - val_loss: 24.2493
# Epoch 54/100
# 328/328 [==============================] - 0s 132us/sample - loss: 25.7103 - val_loss: 24.7855
# Epoch 55/100
# 328/328 [==============================] - 0s 145us/sample - loss: 26.6340 - val_loss: 29.1278
# Epoch 56/100
# 328/328 [==============================] - 0s 126us/sample - loss: 26.2866 - val_loss: 38.0800
# Epoch 57/100
# 328/328 [==============================] - 0s 128us/sample - loss: 28.7029 - val_loss: 23.9963
# Epoch 58/100
# 328/328 [==============================] - 0s 129us/sample - loss: 26.5296 - val_loss: 36.7162
# Epoch 59/100
# 328/328 [==============================] - 0s 128us/sample - loss: 26.3466 - val_loss: 23.8511
# Epoch 60/100
# 328/328 [==============================] - 0s 136us/sample - loss: 26.1797 - val_loss: 23.3706
# Epoch 61/100
# 328/328 [==============================] - 0s 143us/sample - loss: 28.2505 - val_loss: 24.3777
# Epoch 62/100
# 328/328 [==============================] - 0s 140us/sample - loss: 26.3238 - val_loss: 26.1092
# Epoch 63/100
# 328/328 [==============================] - 0s 117us/sample - loss: 27.4297 - val_loss: 32.9110
# Epoch 64/100
# 328/328 [==============================] - 0s 131us/sample - loss: 35.6169 - val_loss: 23.6690
# Epoch 65/100
# 328/328 [==============================] - 0s 122us/sample - loss: 25.7545 - val_loss: 24.0613
# Epoch 66/100
# 328/328 [==============================] - 0s 124us/sample - loss: 34.9540 - val_loss: 33.1835
# Epoch 67/100
# 328/328 [==============================] - 0s 136us/sample - loss: 25.3572 - val_loss: 23.6375
# Epoch 68/100
# 328/328 [==============================] - 0s 129us/sample - loss: 23.8221 - val_loss: 24.4313
# Epoch 69/100
# 328/328 [==============================] - 0s 120us/sample - loss: 28.6614 - val_loss: 38.6362
# Epoch 70/100
# 328/328 [==============================] - 0s 126us/sample - loss: 35.8248 - val_loss: 44.1521
# Epoch 71/100
# 328/328 [==============================] - 0s 126us/sample - loss: 31.1401 - val_loss: 34.8905
# Epoch 72/100
# 328/328 [==============================] - 0s 130us/sample - loss: 32.8913 - val_loss: 38.3429
# Epoch 73/100
# 328/328 [==============================] - 0s 128us/sample - loss: 26.8493 - val_loss: 36.8611
# Epoch 74/100
# 328/328 [==============================] - 0s 130us/sample - loss: 30.5452 - val_loss: 35.9942
# Epoch 75/100
# 328/328 [==============================] - 0s 128us/sample - loss: 25.7089 - val_loss: 61.8234
# Epoch 76/100
# 328/328 [==============================] - 0s 154us/sample - loss: 40.5326 - val_loss: 29.1406
# Epoch 77/100
# 328/328 [==============================] - 0s 129us/sample - loss: 26.6754 - val_loss: 23.8153
# Epoch 78/100
# 328/328 [==============================] - 0s 132us/sample - loss: 31.7981 - val_loss: 34.0970
# Epoch 79/100
# 328/328 [==============================] - 0s 124us/sample - loss: 26.5719 - val_loss: 24.8828
# Epoch 80/100
# 328/328 [==============================] - 0s 145us/sample - loss: 29.7107 - val_loss: 26.9873
# Epoch 81/100
# 328/328 [==============================] - 0s 144us/sample - loss: 26.4260 - val_loss: 31.2922
# Epoch 82/100
# 328/328 [==============================] - 0s 128us/sample - loss: 29.1717 - val_loss: 45.7446
# Epoch 83/100
# 328/328 [==============================] - 0s 159us/sample - loss: 29.3569 - val_loss: 28.6940
# Epoch 84/100
# 328/328 [==============================] - 0s 133us/sample - loss: 28.7407 - val_loss: 45.4231
# Epoch 85/100
# 328/328 [==============================] - 0s 146us/sample - loss: 27.3872 - val_loss: 24.6489
# Epoch 86/100
# 328/328 [==============================] - 0s 139us/sample - loss: 28.5877 - val_loss: 54.7367
# Epoch 87/100
# 328/328 [==============================] - 0s 133us/sample - loss: 30.7775 - val_loss: 40.4040
# Epoch 88/100
# 328/328 [==============================] - 0s 127us/sample - loss: 27.5262 - val_loss: 47.8597
# Epoch 89/100
# 328/328 [==============================] - 0s 120us/sample - loss: 29.3949 - val_loss: 25.6453
# Epoch 90/100
# 328/328 [==============================] - 0s 124us/sample - loss: 28.2396 - val_loss: 60.6674
# Epoch 91/100
# 328/328 [==============================] - 0s 127us/sample - loss: 29.6482 - val_loss: 29.4945
# Epoch 92/100
# 328/328 [==============================] - 0s 121us/sample - loss: 28.4246 - val_loss: 24.9177
# Epoch 93/100
# 328/328 [==============================] - 0s 141us/sample - loss: 24.8101 - val_loss: 27.3769
# Epoch 94/100
# 328/328 [==============================] - 0s 142us/sample - loss: 30.5757 - val_loss: 29.9180
# Epoch 95/100
# 328/328 [==============================] - 0s 126us/sample - loss: 40.2443 - val_loss: 24.3119
# Epoch 96/100
# 328/328 [==============================] - 0s 142us/sample - loss: 24.5442 - val_loss: 33.3360
# Epoch 97/100
# 328/328 [==============================] - 0s 119us/sample - loss: 28.7481 - val_loss: 33.7881
# Epoch 98/100
# 328/328 [==============================] - 0s 124us/sample - loss: 28.0722 - val_loss: 27.3631
# Epoch 99/100
# 328/328 [==============================] - 0s 128us/sample - loss: 27.5227 - val_loss: 42.7958
# Epoch 100/100
# 328/328 [==============================] - 0s 117us/sample - loss: 27.0211 - val_loss: 28.1176

# %%
import numpy as np
test_x = np.reshape([1.2, 0, 8.14e+00, 0.0e+00, 5.3e-01, 6.14e+00, 9.170e+01, 3.97e+00, 4, 3.07e+02, 2.10e+01, 3.96e+02, 1.872e+01],(-1, 13))

test_y = model.predict(test_x)

print(test_y)
# Out:
# [[16.847813]]
